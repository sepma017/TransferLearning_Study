# %% [markdown]
# # 신경망 기초
# - 딥러닝 모델에 필수적인 신경망의 기본 개념에 친숙해져 본다.

# %% [markdown]
# ## 단순한 선형 뉴런
# - 선형 뉴런은 신경망에서 가장 기본적인 구성 요소다.
# - $\overrightarrow{X} = (x_1, x_2, ..., x_n)$은 입력 벡터를 나타내며 $w_i$는 뉴런의 가중치다.
# - 훈련 데이터 세트에 구성된 입력 세트, 목푯값, 선형 뉴런은 훈련 세트가 주어지면 해당 목푯값에 매핑할 수 있는 선형 변환을 시도한다.
# - 기본적으로 선형 뉴런은 입출력 관계를 선형함수 $W^T\overrightarrow{X}=\overrightarrow{y}$에 근사한다.

# %% [markdown]
# ![전이학습_2-1.PNG](data:image/png;base64,...)

# %% [markdown]
# ### 단순한 뉴런으로 간단한 문제를 모델링 한다.
# #### 예) 직원 A가 점심을 구입할 때 음식은 피시(fish), 케첩(ketchup), 칩스(chips)가 있다. 메뉴를 각각 구입할 수 있는데 점원은 총 식사 가격만 알려준다. 며칠 후 각 메뉴의 가격을 알아낼 수 있을까?
# - 선형 신경 유닛을 사용해 이 문제를 나타낸다.
# - $\overrightarrow{X}=(x_{fish}, x_{ketchup}, x_{chips})$와 그에 상응하는 가중치 $(w_{fish}, w_{ketchup}, w_{chips})$가 있다.
# - 각 식사 가격은 각 구성 메뉴의 가격에 선형 제약으로 이루어진다.

# %% [markdown]
# ![전이학습_2-2.PNG](data:image/png;base64,...)

# %% [markdown]
# - 앞의 선형 방정식이 제공한 모델에 $t_n$을 실제 가격으로, $y_n$을 추정치로 넣어보자.
# - 타깃과 추정치 간의 잔차 가격 차이는 $t_n - y_n$이다.
# - 잔차 가격의 차이는 양수 또는 음수가 될 수 있으므로 총 오차가 제로가 되면 무효가 될 것 => **잔차 제곱합(sum squared residuals)**사용!

# %% [markdown]
# ![전이학습_2-3.PNG](data:image/png;base64,...)

# %% [markdown]
# - $E$의 오차를 최소화할 수 있다면 항목당 가중치/가격 세트를 잘 예측할 수 있을 것 => 최적화 문제에 도달!
